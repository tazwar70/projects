# %% [markdown]
# # **Lecture 3-2**

# %% [markdown]
# # Question 1
# For $x=6-7i$ find the angle(x) and the abs(x)

# %%
import numpy as np
x = 6-7j
print(x)
print(np.angle(x))
print(np.abs(x))
# Out:
# (6-7j)
# -0.8621700546672264
# 9.219544457292887

# %% [markdown]
# # Question 2
# Find the real part and imaginary part of $\sqrt{3+5i}$

# %%
x = np.sqrt(3+5j)
print(f'real = {np.real(x)}\nimaginary = {np.imag(x)}')
# Out:
# real = 2.101303392521568
# imaginary = 1.189737764140758

# %% [markdown]
# # **Lecture 4**

# %% [markdown]
# # Question 3
# For $x=3+8i$ fint the acsc(x)

# %%
x=3+8j
# could not find the python equivalent for MATLAB acsc

# %% [markdown]
# # Question 4
# For x in the range $0\le x \le 2\pi$
#
# Calculate:
# >$\tan(2x) - 2\tan(x)/(1-\tan^{2}(x))$

# %%
x = np.arange(0,2*np.pi,np.pi/2)
y = np.tan(2*x) - ((2*np.tan(x))/(1-(np.tan(x))**2))
print(y)
# Out:
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 4.93038066e-32]

# %% [markdown]
# # Question 5
# For x in the range $-10 \le x \le 10$ plot
# >$y = sinh^{-1}x - ln(x+\sqrt{x^{2}+1}$

# %%
import matplotlib.pyplot as plt
x = np.arange(-10,10,0.1)
y = np.arcsinh(x) - np.log(x + np.sqrt(x**2 + 1))
plt.plot(x,y)

# %% [markdown]
# # Question 6
# Create a function called cone that computes the volume V of a cone
# whose height is h and whose radius is r. (Do not forget to check if a file
# already exists by that name!) The volume is given by $V=\frac{\pi r^{2}h}{3}$.
#
# For r=4
# and h=70 the result is:

# %%
def cone(r,h):
  V=((np.pi)*(r**2)*(h))/3
  print(f'Volume of the cone = {V}')

cone(4,70)
# Out:
# Volume of the cone = 1172.8612573401895

# %% [markdown]
# # Question 7
# Write a function to calculate the area, $A = 2\pi rh +2\pi r^{2}$,
# and the volume, $V=\pi r^{2}h$, of the cylinder.
# A and B for r=3 and h=5 are

# %%
pi = np.pi
def calc(r,h):
  A = 2*pi*r*h + 2*pi*(r**2)
  V = pi*(r**2)*h
  print(f'Area = {A}\nVolume = {V}')

calc(3,5)
# Out:
# Area = 150.79644737231007
# Volume = 141.3716694115407

# %% [markdown]
# # Question 8
# The equation $e^{-0.1x}sin(x+2)=0.1$ has two solutions in the interval $1<x<5$. The solutions are:

# %%
from scipy.optimize import root
from numpy import *
from matplotlib.pylab import plot
y = lambda x: (exp(-0.1*x))*(sin(x+2))
print(f'for x0 = 2.5,\n\n{root(y,2.5)}\n\nfor x0 = 3.5,\n\n{root(y,3.5)}')
x = arange(1,5,0.01)
plot(x,y(x))
# Out:
# for x0 = 2.5,
#
#     fjac: array([[-1.]])
#      fun: array([-3.45635857e-15])
#  message: 'The solution converged.'
#     nfev: 13
#      qtf: array([-2.34620995e-09])
#        r: array([0.89211452])
#   status: 1
#  success: True
#        x: array([1.14159265])
#
# for x0 = 3.5,
#
#     fjac: array([[-1.]])
#      fun: array([-2.47455873e-15])
#  message: 'The solution converged.'
#     nfev: 7
#      qtf: array([-1.40271797e-09])
#        r: array([-0.65160266])
#   status: 1
#  success: True
#        x: array([4.28318531])

# %% [markdown]
# # Question 9
#
# The function $y = 0.5 + e^{-0.6x}sin(3x+2)$ has one minimum point in the interval $-8\le x \le -7$. Find the value of x at the minimum.

# %% [markdown]
# # Question 10
# Create a primary function that uses a function handle with a nested
# function to compute the minimum of the function $20x^{x}-200x+12$ over
# the range $0\le x \le 10$.

# %% [markdown]
# # Question 11
# Write a function to compute $y = x^{2}-4$. The values returned by fminsearch(@fun1,-1) and fzero(@fun1,0) are:

# %% [markdown]
# # Question 12
# Find the depth $d$ and the angle $\theta$ to minimize the perimeter length(L) of the  channel shown below to provide an area($S$) of 380 $ft^{2}$
#
# >$L = \frac{S}{d} - \frac{d}{\tan(\theta)} + \frac{2d}{\sin(\theta)}$

# %% [markdown]
# # Question 13
# Write an anonympus function to calculate $\sqrt{e^{3x}+y^{3}-\sin(x)}$ for x = 4 and y = 3.

# %%
square_root = lambda x,y : sqrt(exp(3*x) + y**3 - sin(x))
print(f'For x=4 and y=3, solution is,\n{square_root(4,3)}')
# Out:
# For x=4 and y=3, solution is,
# 403.4631931434381

# %% [markdown]
# # Question 14
# Create an anonymous function for $10cos(e^{-2x})$ and use it to plot the function over the range $0\le x \le 2$.

# %%
y = lambda x: 10*cos(e**(-2*x))
plot(arange(0,2,0.01),y(arange(0,2,0.01)))

# %% [markdown]
# # Question 15
# Assume $f=@(x) x^{3}$ $g = @(x) 5sin(x)$. Calculate $h(x,y) = g(f(x)) + 5y$. for h(6,1)

# %%
f = lambda x: x**3
g = lambda x: 5*sin(x)
h = lambda x,y: g(f(x)) + 5*y
print(h(6,1))
# Out:
# 8.480292441724558

# %% [markdown]
# # Question 17
# Create four anonymous functions to represent the function $6e^{3cos(x^{2})}$ which is composed of the functions $h(z) = 6e^{z}, g(y) = 3cos(y)$ and $f(x) x^{2}$. Use anonymous functions to plot $6e^{3cos(x^{2})}$ over the range $0\le x \le 4$

# %%
h = lambda z: 6*exp(z)
g = lambda y: 3*cos(y)
f = lambda x: x**2
eqn = lambda x: h(g(f(x)))
plot(arange(0,4,0.01),eqn(arange(0,4,0.01)))
