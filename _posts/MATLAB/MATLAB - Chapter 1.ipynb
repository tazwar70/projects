# %% [markdown]
# # **Lecture 1**

# %% [markdown]
# # Question 1
# What answer is produced by the following MATLAB expressions.
# 10^-1/2 and 10^(-1/2)
#
# Answer, for Python

# %%
first_eqn = (10**-1)/2
second_eqn = 10**(-1/2)
print(first_eqn)
print(second_eqn)
# Out:
# 0.05
# 0.31622776601683794

# %% [markdown]
# # Question 2
# The answer to compute the following expression, 3^4-11-8/4∗2, using
# MATLAB is:
#
# Python code for this

# %%
ans =  (3**4)-11-((8/4)*2)
print(ans)
# Out:
# 66.0

# %% [markdown]
# # Question 3
# Given x=-5+9i and y=6-2i, The answers to the following expressions are
# >$x+2y$ and $\frac{x^{2}}{y}$
#
# Python code

# %%
import numpy as np
x = np.complex(-5,9)
y = np.complex(6,-2)
print(f'x = {x} \ny = {y}')
print(f'x+2y = {x+2*y}')
print(f'x^2/y = {(x**2)/y}')
# Out:
# x = (-5+9j)
# y = (6-2j)
# x+2y = (7+5j)
# x^2/y = (-3.9-16.299999999999997j)

# %% [markdown]
# # Question 3
# Use MATLAB to determine how many elements are in the following
# array and what is the 25th element
# >$cos(0):0.01:log10(100)$
#
# Python Code

# %%
x = np.arange(np.cos(0),np.log10(100)+0.01,0.01)
print(x)
print(np.shape(x))
print(f'The 25th element is {x[24]}')
# Out:
# [1.   1.01 1.02 1.03 1.04 1.05 1.06 1.07 1.08 1.09 1.1  1.11 1.12 1.13
#  1.14 1.15 1.16 1.17 1.18 1.19 1.2  1.21 1.22 1.23 1.24 1.25 1.26 1.27
#  1.28 1.29 1.3  1.31 1.32 1.33 1.34 1.35 1.36 1.37 1.38 1.39 1.4  1.41
#  1.42 1.43 1.44 1.45 1.46 1.47 1.48 1.49 1.5  1.51 1.52 1.53 1.54 1.55
#  1.56 1.57 1.58 1.59 1.6  1.61 1.62 1.63 1.64 1.65 1.66 1.67 1.68 1.69
#  1.7  1.71 1.72 1.73 1.74 1.75 1.76 1.77 1.78 1.79 1.8  1.81 1.82 1.83
#  1.84 1.85 1.86 1.87 1.88 1.89 1.9  1.91 1.92 1.93 1.94 1.95 1.96 1.97
#  1.98 1.99 2.  ]
# (101,)
# The 25th element is 1.2400000000000002

# %% [markdown]
# # Question 5
# Find the roots of the following polynomial
# >$290-11x+6x^{2}-x^{3}$

# %%
roots = [-1,6,-11,290]
print(f'The roots are,\n{np.roots(roots)}')
# Out:
# The roots are,
# [ 8.6238489 +0.j         -1.31192445+5.64858661j -1.31192445-5.64858661j]

# %% [markdown]
# # Question 6
# Plot the following functions,
# >$y=2\sqrt{x}$ and $z=4sin(3x)$
# for $0\leqslant x \leqslant 5$

# %%
import matplotlib.pyplot as plt
x = np.arange(0,5,0.01)
y = 2*np.sqrt(x)
z = 4*np.sin(3*x)
plt.plot(x,y)
plt.plot(x,z)
plt.xlabel('x')
plt.ylabel('y and z')
plt.legend(['y','z'])

# %% [markdown]
# # Question 7
# Plot $y=4\sqrt{6x+1}$ and $z=5e^{0.3x} -2x$ over $ 0 \leqslant x \leqslant 5$

# %%
x = np.arange(0,5,0.01)
y = 4*np.sqrt(6*x+1)
z = 5*np.exp(0.3*x) - 2*x
plt.plot(x,y)
plt.plot(x,z)

# %% [markdown]
# # Question 8
# Plot $s = 4sin(7t+5) + \sqrt{6t+2}$ over $0 \leqslant t \leqslant 5$

# %%
t = np.arange(0,5,0.01)
s = 4*np.sin(7*t + 5) + np.sqrt(6*t + 2)
plt.plot(t,s)

# %% [markdown]
# # **Lecture 2-1**

# %% [markdown]
# # Question 9
# The volume of a sphere can be
# calculated from: $V = \frac{4}{3} \pi r^{3}$ , where
# r is the radius. Write a script file
# that prompts the user to enter a
# radius, computes the volume, and
# displays the result. For r=8, V is:

# %%
r = int(input('r = '))
v = float((4/3)*(np.pi)*(r**3))
print(f'Volume of the sphere = {v}')
# Out:
# r = 2
# Volume of the sphere = 33.510321638291124

# %% [markdown]
# # Question 10
# Find the nthroot of a number.

# %%
n = float(input('n = '))
root= float(input('root = '))
print(f'nthroot = {np.power(root,1/n)}')
# Out:
# n = 3
# root = 27
# nthroot = 3.0

# %% [markdown]
# # Question 11
# The ideal gas law relates the pressure P, volume V,
# absolute temperature T, and amount of gas n. The law is
# $P = \frac{nRT}{V}$
# where R is the gas constant. An engineer must design a large natural gas
# storage tank to be expandable to maintain the pressure constant at 2.2 atm.
# In December when the temperature is 4°F (-15°C), the volume of gas in the
# tank is 18 500 $ft^{3}$. What will the volume of the same quantity of gas be in
# July when the temperature is 88°F (31°C)? (Hint: Use the fact that n, R, and
# P are constant in this problem. Note also that K=C+273.2.)

# %%
V1 = 18500
T1 = -15+273.2
T2 = 31+273.2
print(f'T1 = {T1}\nT2 = {T2}')
# t1/v1 = t2/v2
# v1/t1 = v2/t2
V2 = (V1*T2)/T1
print(f'The Volume in July = {V2}')
# Out:
# T1 = 258.2
# T2 = 304.2
# The Volume in July = 21795.894655305965

# %% [markdown]
# # Question 12
# The Fourier series is a series representation of a periodic
# function in terms of sines and cosines. The Fourier series representation of the
# function
#
# > $f(x) = 1 $ ; $ 0 < x < \pi$
# > $f(x) = -1 $  ; $-\pi < x < 0$
#
# is
# > $\frac{4}{\pi} ( \frac{\sin x}{1} + \frac{\sin 3x}{3} + \frac{\sin 5x}{5} + \frac{\sin 7x}{7} + ... )$
#
# Plot on the same graph the function f(x) and its series representation, using the
# four terms shown.

# %%
pi = np.pi
x1 = np.linspace(0,pi,1000)
f1 = np.linspace(1,1,1000)
x2 = np.linspace(-pi,0,1000)
f2 = np.linspace(-1,-1,1000)
x3 = np.linspace(-pi,pi,1000)
f3 = (4/pi)*( (np.sin(x3))/1 + (np.sin(3*x3))/3 + (np.sin(5*x3))/5 + (np.sin(7*x3))/7)
plt.plot(x1,f1)
plt.plot(x2,f2)
plt.plot(x3,f3)
plt.legend(['f1(x1)','f2(x2)','f2(x2)'])

# %% [markdown]
# # Question 13
# Write a script file to compute the three roots of the cubic
# equation $x^{3} + ax^{2} +bx +c = 0$.
#
# Use the input function to let the user
# enter values for a, b, and c.
# The answers for a=1, b=-8, c=-12 are

# %%
a = float(input('a = '))
b = float(input('b = '))
c = float(input('c = '))
print(np.roots([1.,a,b,c]))
# Out:
# a = 1
# b = -8
# c = -12
# [ 3.+0.00000000e+00j -2.+2.64654513e-08j -2.-2.64654513e-08j]

# %% [markdown]
# # Question 14
# Suppose x takes on the values x = 1, 1.2, 1.4, 1.6, … , 5. Use
# MATLAB to compute the array y that results from the function y = 7
# sin(4x). The number of elements are in the array y and the value of its third
# element are.

# %%
x = np.arange(1,5.2,0.2)
y = 7*(np.sin(4*x))
plt.plot(x,y)
print(f'Number of Elements = {np.shape(y)}\nValue of 3rd element = {y[2]}')
# Out:
# Number of Elements = (21,)
# Value of 3rd element = -4.418866465106252
